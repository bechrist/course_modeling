# %% [markdown]
# # Course Modeling Main Notebook
# ### 25 June 2022

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys; 

PROJ_DIR = os.path.realpath('..')

sys.path.insert(0, PROJ_DIR)
from course_modeling.builder import CourseBuilder
from course_modeling.trajectory import planar_cubic_g2_interpolant

# %% [markdown]
# ## Select and Load Data

# %%
DATA_DIR = os.path.abspath(os.path.join(PROJ_DIR,'data'))
INPUT = '16_19_lincoln_endurance.json'

builder = CourseBuilder(INPUT, DATA_DIR)

# %%
builder.gates()
builder._course.plot()
